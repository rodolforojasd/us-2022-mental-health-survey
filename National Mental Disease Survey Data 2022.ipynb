# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd '/content/drive/MyDrive/Projects/Data Analysis/US Mental Disease Survey 2022/'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Projects/Data Analysis/US Mental Disease Survey 2022

# %%
df = pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')

# %%
df.head()
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 0    BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022           PA
# 1    BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022           SD
# 2    BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022           ID
# 3    BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022           MD
# 4  BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022           WI
#
#    LocationDesc Datasource          Class                     Topic  \
# 0  Pennsylvania      BRFSS  Mental Health  Frequent mental distress
# 1  South Dakota      BRFSS  Mental Health  Frequent mental distress
# 2         Idaho      BRFSS  Mental Health  Frequent mental distress
# 3      Maryland      BRFSS  Mental Health  Frequent mental distress
# 4     Wisconsin      BRFSS  Mental Health  Frequent mental distress
#
#                                             Question Data_Value_Unit  ...  \
# ...

# %%
df_splits = np.array_split(df, 5)


df1, df2, df3, df4, df5 = df_splits
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
for i, df in enumerate([df1, df2, df3, df4, df5], start=1):
    df.to_csv(f'/content/drive/MyDrive/Projects/Data Analysis/US Mental Disease Survey 2022/Alzheimer_s_Disease_and_Healthy_Aging_Data_{i}.csv', encoding='utf-8', index=False)

# %%
# Out:
#                                           RowId  YearStart  YearEnd  \
# 113658    BRFSS~2020~2020~32~Q45~TOC13~AGE~RACE       2020     2020
# 113659  BRFSS~2020~2020~72~Q34~TOC09~AGE~GENDER       2020     2020
# 113660    BRFSS~2020~2020~46~Q35~TOC03~AGE~RACE       2020     2020
# 113661    BRFSS~2020~2020~44~Q45~TOC13~AGE~RACE       2020     2020
# 113662    BRFSS~2020~2020~66~Q45~TOC13~AGE~RACE       2020     2020
#
#        LocationAbbr  LocationDesc Datasource           Class  \
# 113658           NV        Nevada      BRFSS  Overall Health
# 113659           PR   Puerto Rico      BRFSS  Overall Health
# 113660           SD  South Dakota      BRFSS  Overall Health
# 113661           RI  Rhode Island      BRFSS  Overall Health
# 113662           GU          Guam      BRFSS  Overall Health
#
#                                                     Topic  \
# 113658  Fair or poor health among older adults with ar...
# 113659                     Prevalence of sufficient sleep
# ...
